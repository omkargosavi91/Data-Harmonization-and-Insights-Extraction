# %% [markdown]
# Data Harmonization and Insights Extraction

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# # Data Aquisition (Dataset1)

# %% [markdown]
# ### 1) Load datasets into Python.

# %%
dataset1 = pd.read_excel(r'C:\Users\HP\Desktop\Project 2\dataset_1.xlsx')
dataset1
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# ...

# %% [markdown]
# ### 2) Inspect and explore data structures using .info() and .head().

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(7)
# memory usage: 43.6 KB

# %%
dataset1.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1 2011-01-01       1   0     1   0    False        6           1
# 1        2 2011-01-01       1   0     1   1    False        6           1
# 2        3 2011-01-01       1   0     1   2    False        6           1
# 3        4 2011-01-01       1   0     1   3    False        6           1
# 4        5 2011-01-01       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %% [markdown]
# # 3) Document initial observations about data quality and completeness.

# %%
dataset1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
dataset1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data Aquisition (Dataset2)

# %% [markdown]
# ## 1) Load datasets into Python.

# %%
dataset2 = pd.read_excel(r'C:\Users\HP\Desktop\Project 2\dataset_2.xlsx')
dataset2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %% [markdown]
# ## 2) Inspect and explore data structures using .info() and .head().

# %%
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB

# %%
dataset2.head()
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# # 3) Document initial observations about data quality and completeness.

# %%
dataset2.isnull().sum()
# Out:
# Unnamed: 0     0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
dataset2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Data Aquisition (Dataset3)

# %% [markdown]
# ## 1) Load datasets into Python.

# %%
dataset3 = pd.read_excel(r'C:\Users\HP\Desktop\Project 2\dataset_3.xlsx')
dataset3
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620 2011-01-29       1   0     1   1    False        6           1
# 1        621 2011-01-29       1   0     1   2    False        6           1
# 2        622 2011-01-29       1   0     1   3    False        6           1
# 3        623 2011-01-29       1   0     1   4    False        6           1
# 4        624 2011-01-29       1   0     1   6    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 385      615 2011-01-28       1   0     1  20    False        5           2
# 386      616 2011-01-28       1   0     1  21    False        5           2
# 387      617 2011-01-28       1   0     1  22    False        5           1
# 388      618 2011-01-28       1   0     1  23    False        5           1
# 389      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %% [markdown]
# ## 2) Inspect and explore data structures using .info() and .head().

# %%
dataset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    datetime64[ns]
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 46.2 KB

# %%
dataset3.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620 2011-01-29       1   0     1   1    False        6           1
# 1      621 2011-01-29       1   0     1   2    False        6           1
# 2      622 2011-01-29       1   0     1   3    False        6           1
# 3      623 2011-01-29       1   0     1   4    False        6           1
# 4      624 2011-01-29       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2

# %% [markdown]
# # 3) Document initial observations about data quality and completeness.

# %%
dataset3.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
dataset3.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Phase 2: Data Wrangling

# %% [markdown]
# ## Dataset_1 and Dataset_2 Integration

# %% [markdown]
# ### Merge the datasets using common keys.

# %%
merge_1_and_2 = pd.merge(dataset1,dataset2,on='instant',how = 'inner')
merge_1_and_2
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
# ...

# %% [markdown]
# ### Handle missing values using appropriate imputation techniques.

# %%
merge_1_and_2.isnull().sum()
# Out:
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# Unnamed: 0     0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
merge_1_and_2
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
# ...

# %%
bfill = merge_1_and_2.fillna(method='bfill')
bfill.isnull().sum()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8952\1917959559.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   bfill = merge_1_and_2.fillna(method='bfill')
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# Unnamed: 0    0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
merge_1_and_2
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
# ...

# %% [markdown]
# ## Perform basic statistical analysis to evaluate central tendencies (mean, median, mode).

# %%
d = pd.DataFrame({'value':[4,6,8,3,7,9,4,7,4]})
d['value'].mean()
# Out:
# 5.777777777777778

# %%
d['value'].median()
# Out:
# 6.0

# %%
d['value'].mode()
# Out:
# 0    4
# Name: value, dtype: int64

# %% [markdown]
# # Task 2: Dataset_3 Integration

# %% [markdown]
# ### Concatenate Dataset_3 with the merged dataset.

# %%
vertical_concat = pd.concat([dataset1, dataset2], axis=0)

# %%
vertical_concat
# Out:
#      instant     dteday  season   yr  mnth   hr holiday  weekday  weathersit  \
# 0          1 2011-01-01     1.0  0.0   1.0  0.0   False      6.0         1.0
# 1          2 2011-01-01     1.0  0.0   1.0  1.0   False      6.0         1.0
# 2          3 2011-01-01     1.0  0.0   1.0  2.0   False      6.0         1.0
# 3          4 2011-01-01     1.0  0.0   1.0  3.0   False      6.0         1.0
# 4          5 2011-01-01     1.0  0.0   1.0  4.0   False      6.0         1.0
# ..       ...        ...     ...  ...   ...  ...     ...      ...         ...
# 605      606        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 606      607        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 607      608        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 608      609        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 609      610        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
#
# ...

# %%
horizontal_concat = pd.concat([dataset1, dataset2], axis=1)

# %%
horizontal_concat
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
# ...

# %% [markdown]
# ### Perform detailed missing value analysis and outlier detection.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = dataset1

# %%
df
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# ...

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sn.distplot(dataset1['weathersit'])

plt.subplot(1,2,2)
sn.distplot(dataset1['temp'])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10408\1200407957.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(dataset1['weathersit'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_10408\1200407957.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(dataset1['temp'])

# %% [markdown]
# # Phase 3: Data Analysis

# %% [markdown]
# ### Task 3 with dataset1: Advanced Statistical Analysis

# %% [markdown]
# #### Analyze skewness of numerical columns and apply transformations as needed.

# %% [markdown]
# #### Compute correlations between attributes to identify relationships.

# %% [markdown]
# #### Visualize key insights using heatmaps, scatter plots, and boxplots.

# %%
dataset1['weathersit'].skew()
# Out:
# 1.050244188891752

# %%
dataset1['weathersit'].mean()
# Out:
# 1.477049180327869

# %%
dataset1['weathersit'].std()
# Out:
# 0.64349554502012

# %%
Upper_Value_weathersit = 1.477049180327869 + 3*0.64349554502012

# %%
Upper_Value_weathersit
# Out:
# 3.407535815388229

# %%
Lower_Value_weathersit = 1.477049180327869 - 3*0.64349554502012

# %%
Lower_Value_weathersit
# Out:
# -0.4534374547324911

# %%
dataset1[(dataset1['weathersit']>3.407535815388229) | (dataset1['weathersit']<-0.4534374547324911)]
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 585      586 2011-01-26       1   0     1  16    False        3           4
#
#      temp
# 585  0.22

# %%
percenile_25th = dataset1['weathersit'].quantile(0.25)

# %%
percenile_25th
# Out:
# 1.0

# %%
percenile_50th = dataset1['weathersit'].quantile(0.50)

# %%
percenile_50th
# Out:
# 1.0

# %%
percenile_75th = dataset1['weathersit'].quantile(0.75)

# %%
percenile_75th
# Out:
# 2.0

# %%
percenile_100th = dataset1['weathersit'].quantile(1.0)

# %%
percenile_100th
# Out:
# 4.0

# %%
iqr = percenile_75th - percenile_25th

# %%
iqr
# Out:
# 1.0

# %%
max_side_value = percenile_75th + 1.5*iqr

# %%
max_side_value
# Out:
# 3.5

# %%
mai_side_value = percenile_25th - 1.5*iqr
mai_side_value
# Out:
# -0.5

# %%
dataset1[dataset1['weathersit'] < mai_side_value]
# Out:
# Empty DataFrame
# Columns: [instant, dteday, season, yr, mnth, hr, holiday, weekday, weathersit, temp]
# Index: []

# %%
dataset1[dataset1['weathersit'] > max_side_value]
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 585      586 2011-01-26       1   0     1  16    False        3           4
#
#      temp
# 585  0.22

# %%
dataset1.describe()
# Out:
#           instant                         dteday  season     yr   mnth  \
# count  610.000000                            610   610.0  610.0  610.0
# mean   305.500000  2011-01-13 19:47:24.590163968     1.0    0.0    1.0
# min      1.000000            2011-01-01 00:00:00     1.0    0.0    1.0
# 25%    153.250000            2011-01-07 00:00:00     1.0    0.0    1.0
# 50%    305.500000            2011-01-14 00:00:00     1.0    0.0    1.0
# 75%    457.750000            2011-01-21 00:00:00     1.0    0.0    1.0
# max    610.000000            2011-01-28 00:00:00     1.0    0.0    1.0
# std    176.236111                            NaN     0.0    0.0    0.0
#
#                hr     weekday  weathersit        temp
# count  610.000000  610.000000  610.000000  610.000000
# mean    11.795082    2.977049    1.477049    0.196885
# min      0.000000    0.000000    1.000000    0.020000
# 25%      6.000000    1.000000    1.000000    0.160000
# 50%     12.000000    3.000000    1.000000    0.200000
# ...

# %%
sn.boxplot(dataset1['weathersit'])
# Out:
# <Axes: ylabel='weathersit'>

# %%
sn.scatterplot(dataset1['weathersit'])
# Out:
# <Axes: ylabel='weathersit'>

# %%
sn.histplot(dataset1['weathersit'])
# Out:
# <Axes: xlabel='weathersit', ylabel='Count'>

# %%
dataset1['temp'].skew()
# Out:
# 0.6650867915670247

# %%
dataset1['temp'].mean()
# Out:
# 0.19688524590163933

# %%
dataset1['temp'].std()
# Out:
# 0.08130384503268402

# %%
Upper_Value_temp = 0.19688524590163933 + 3*0.08130384503268402

# %%
Upper_Value_temp
# Out:
# 0.44079678099969144

# %%
Lower_Value_temp = 0.19688524590163933 - 3*0.08130384503268402

# %%
Lower_Value_temp
# Out:
# -0.047026289196412746

# %%
dataset1[(dataset1['temp']>0.44079678099969144) | (dataset1['temp']<-0.047026289196412746)]
# Out:
#     instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 13       14 2011-01-01       1   0     1  13    False        6           2
# 14       15 2011-01-01       1   0     1  14    False        6           2
# 23       24 2011-01-01       1   0     1  23    False        6           2
# 24       25 2011-01-02       1   0     1   0    False        0           2
# 27       28 2011-01-02       1   0     1   3    False        0           2
# 28       29 2011-01-02       1   0     1   4    False        0           2
#
#     temp
# 13  0.46
# 14  0.46
# 23  0.46
# 24  0.46
# 27  0.46
# 28  0.46

# %%
percenile_25th = dataset1['temp'].quantile(0.25)

# %%
percenile_25th
# Out:
# 0.16

# %%
percenile_50th = dataset1['temp'].quantile(0.50)

# %%
percenile_50th
# Out:
# 0.2

# %%
percenile_75th = dataset1['temp'].quantile(0.75)

# %%
percenile_75th
# Out:
# 0.235

# %%
percenile_100th = dataset1['temp'].quantile(1.0)

# %%
percenile_100th
# Out:
# 0.46

# %%
iqr = percenile_75th - percenile_25th

# %%
iqr
# Out:
# 0.07499999999999998

# %%
max_side_value = percenile_75th + 1.5*iqr
max_side_value
# Out:
# 0.3475

# %%
mai_side_value = percenile_25th - 1.5*iqr
mai_side_value
# Out:
# 0.04750000000000003

# %%
dataset1[dataset1['temp'] < mai_side_value]
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 479      480 2011-01-22       1   0     1   0    False        6           1
# 480      481 2011-01-22       1   0     1   1    False        6           2
# 481      482 2011-01-22       1   0     1   2    False        6           2
# 482      483 2011-01-22       1   0     1   3    False        6           2
# 483      484 2011-01-22       1   0     1   4    False        6           2
# 484      485 2011-01-22       1   0     1   6    False        6           2
# 485      486 2011-01-22       1   0     1   7    False        6           1
# 486      487 2011-01-22       1   0     1   8    False        6           1
# 487      488 2011-01-22       1   0     1   9    False        6           1
# 488      489 2011-01-22       1   0     1  10    False        6           2
# 501      502 2011-01-22       1   0     1  23    False        6           1
# ...

# %%
dataset1[dataset1['temp'] < max_side_value]
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# ...

# %%
sn.boxplot(dataset1['temp'])
# Out:
# <Axes: ylabel='temp'>

# %%
sn.scatterplot(dataset1['temp'])
# Out:
# <Axes: ylabel='temp'>

# %%
sn.histplot(dataset1['temp'])
# Out:
# <Axes: xlabel='temp', ylabel='Count'>

# %%
dataset2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df2 = dataset2
df2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sn.distplot(df2['hum'])

plt.subplot(1,2,2)
sn.distplot(df2['windspeed'])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8952\3256750724.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df2['hum'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8952\3256750724.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df2['windspeed'])

# %%
dataset2['hum'].skew()
# Out:
# 0.6095529268829645

# %%
dataset2['hum'].mean()
# Out:
# 0.5624754098360656

# %%
dataset2['hum'].std()
# Out:
# 0.1754401555026779

# %%
Upper_Value_hum = 0.5624754098360656 + 3*0.1754401555026779

# %%
Upper_Value_hum
# Out:
# 1.0887958763440992

# %%
Lower_Value_hum = 0.5624754098360656 - 3*0.1754401555026779

# %%
Lower_Value_hum
# Out:
# 0.03615494332803182

# %%
dataset2[(dataset2['hum']>1.0887958763440992) | (dataset2['hum']<0.03615494332803182)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, instant, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %%
percenile_25th = dataset2['hum'].quantile(0.25)

# %%
percenile_25th
# Out:
# 0.4325

# %%
percenile_50th = dataset2['hum'].quantile(0.50)

# %%
percenile_50th
# Out:
# 0.52

# %%
percenile_75th = dataset2['hum'].quantile(0.75)

# %%
percenile_75th
# Out:
# 0.69

# %%
percenile_100th = dataset2['hum'].quantile(1.0)

# %%
percenile_100th
# Out:
# 1.0

# %%
iqr = percenile_75th - percenile_25th

# %%
iqr
# Out:
# 0.25749999999999995

# %%
max_side_value = percenile_75th + 1.5*iqr
max_side_value
# Out:
# 1.07625

# %%
mai_side_value = percenile_25th - 1.5*iqr
mai_side_value
# Out:
# 0.04625000000000007

# %%
dataset2[dataset2['hum'] < mai_side_value]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, instant, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %%
dataset2[dataset2['hum'] < max_side_value]
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
sn.boxplot(dataset2['hum'])
# Out:
# <Axes: ylabel='hum'>

# %%
sn.scatterplot(dataset2['hum'])
# Out:
# <Axes: ylabel='hum'>

# %%
sn.histplot(dataset2['hum'])
# Out:
# <Axes: xlabel='hum', ylabel='Count'>

# %%
dataset2['windspeed'].skew()
# Out:
# 0.3390293755619799

# %%
dataset2['windspeed'].min()
# Out:
# 0.0

# %%
dataset2['windspeed'].std()
# Out:
# 0.12180590946383385

# %%
Upper_Value_windspeed = 0.0 + 3*0.12180590946383385

# %%
Upper_Value_windspeed
# Out:
# 0.36541772839150155

# %%
Lower_Value_windspeed = 0.0 - 3*0.12180590946383385

# %%
Lower_Value_windspeed
# Out:
# -0.36541772839150155

# %%
dataset2[(dataset2['windspeed']>0.36541772839150155) | (dataset2['windspeed']<-0.36541772839150155)]
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 42           42       43  0.2879  0.42     0.4478       1          29   30
# 48           48       49     NaN  0.44     0.4179       0           2    2
# 49           49       50  0.1364  0.47     0.3881       0           1    1
# 51           51       52  0.1061  0.50     0.3881       0          30   30
# 54           54       55  0.1364  0.43     0.3881       7          81   88
# 172         172      173  0.1818  0.69     0.3881       2          60   62
# 175         175      176  0.1667  0.32     0.4925      12          83   95
# 176         176      177  0.1667  0.32     0.4478       5          69   74
# 177         177      178  0.1364  0.29     0.4478       8          68   76
# 178         178      179  0.1212  0.37     0.5522       5          64   69
# 183         183      184  0.1061  0.36     0.3881       1          33   34
# ...

# %%
percenile_25th = dataset2['windspeed'].quantile(0.25)

# %%
percenile_25th
# Out:
# 0.1045

# %%
percenile_50th = dataset2['windspeed'].quantile(0.50)

# %%
percenile_50th
# Out:
# 0.194

# %%
percenile_75th = dataset2['windspeed'].quantile(0.75)

# %%
percenile_75th
# Out:
# 0.2836

# %%
percenile_100th = dataset2['windspeed'].quantile(1.0)

# %%
percenile_100th
# Out:
# 1.0

# %%
iqr = percenile_75th - percenile_25th

# %%
iqr
# Out:
# 0.17910000000000004

# %%
max_side_value = percenile_75th + 1.5*iqr
max_side_value
# Out:
# 0.5522500000000001

# %%
mai_side_value = percenile_25th - 1.5*iqr
mai_side_value
# Out:
# -0.16415000000000007

# %%
dataset2[dataset2['windspeed'] < mai_side_value]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, instant, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %%
dataset2[dataset2['windspeed'] < max_side_value]
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [607 rows x 8 columns]

# %%
sn.boxplot(dataset2['windspeed'])
# Out:
# <Axes: ylabel='windspeed'>

# %%
sn.scatterplot(dataset2['windspeed'])
# Out:
# <Axes: ylabel='windspeed'>

# %%
sn.histplot(dataset2['windspeed'])
# Out:
# <Axes: xlabel='windspeed', ylabel='Count'>

# %%
dataset3
df3 = dataset3
df3
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620 2011-01-29       1   0     1   1    False        6           1
# 1        621 2011-01-29       1   0     1   2    False        6           1
# 2        622 2011-01-29       1   0     1   3    False        6           1
# 3        623 2011-01-29       1   0     1   4    False        6           1
# 4        624 2011-01-29       1   0     1   6    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 385      615 2011-01-28       1   0     1  20    False        5           2
# 386      616 2011-01-28       1   0     1  21    False        5           2
# 387      617 2011-01-28       1   0     1  22    False        5           1
# 388      618 2011-01-28       1   0     1  23    False        5           1
# 389      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sn.distplot(df3['temp'])

plt.subplot(1,2,2)
sn.distplot(df3['atemp'])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8952\1127515431.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df3['temp'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8952\1127515431.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df3['atemp'])

# %%
dataset3['temp'].skew()
# Out:
# 0.479548090660662

# %%
dataset3['temp'].min()
# Out:
# 0.06

# %%
dataset3['temp'].std()
# Out:
# 0.07309535273367

# %%
Upper_Value_temp = 0.06 + 3*0.07309535273367

# %%
Upper_Value_temp
# Out:
# 0.27928605820101

# %%
Lower_Value_temp = 0.06 - 3*0.07309535273367

# %%
Lower_Value_temp
# Out:
# -0.15928605820101

# %%
dataset3[(dataset3['temp']>0.27928605820101) | (dataset3['temp']<-0.15928605820101)]
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 33       653 2011-01-30       1   0     1  12    False        0           1
# 34       654 2011-01-30       1   0     1  13    False        0           1
# 35       655 2011-01-30       1   0     1  14    False        0           1
# 36       656 2011-01-30       1   0     1  15    False        0           1
# 37       657 2011-01-30       1   0     1  16    False        0           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 376      996 2011-02-14       1   0     2   3    False        1           1
# 377      997 2011-02-14       1   0     2   4    False        1           1
# 378      998 2011-02-14       1   0     2   5    False        1           1
# 379      999 2011-02-14       1   0     2   6    False        1           1
# 380     1000 2011-02-14       1   0     2   7    False        1           1
#
# ...

# %%
percenile_25th = dataset3['temp'].quantile(0.25)

# %%
percenile_25th
# Out:
# 0.16

# %%
percenile_50th = dataset3['temp'].quantile(0.50)

# %%
percenile_50th
# Out:
# 0.22

# %%
percenile_75th = dataset3['temp'].quantile(0.75)

# %%
percenile_75th
# Out:
# 0.26

# %%
percenile_100th = dataset3['temp'].quantile(1.0)

# %%
percenile_100th
# Out:
# 0.42

# %%
iqr = percenile_75th - percenile_25th

# %%
iqr
# Out:
# 0.1

# %%
max_side_value = percenile_75th + 1.5*iqr
max_side_value
# Out:
# 0.41000000000000003

# %%
mai_side_value = percenile_25th - 1.5*iqr
mai_side_value
# Out:
# 0.009999999999999981

# %%
dataset3[dataset3['temp'] < mai_side_value]
# Out:
# Empty DataFrame
# Columns: [instant, dteday, season, yr, mnth, hr, holiday, weekday, weathersit, temp, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %%
dataset3[dataset3['temp'] < max_side_value]
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620 2011-01-29       1   0     1   1    False        6           1
# 1        621 2011-01-29       1   0     1   2    False        6           1
# 2        622 2011-01-29       1   0     1   3    False        6           1
# 3        623 2011-01-29       1   0     1   4    False        6           1
# 4        624 2011-01-29       1   0     1   6    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 385      615 2011-01-28       1   0     1  20    False        5           2
# 386      616 2011-01-28       1   0     1  21    False        5           2
# 387      617 2011-01-28       1   0     1  22    False        5           1
# 388      618 2011-01-28       1   0     1  23    False        5           1
# 389      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %%
sn.boxplot(dataset3['temp'])
# Out:
# <Axes: ylabel='temp'>

# %%
sn.scatterplot(dataset3['temp'])
# Out:
# <Axes: ylabel='temp'>

# %%
sn.histplot(dataset3['temp'])
# Out:
# <Axes: xlabel='temp', ylabel='Count'>

# %%
dataset3['atemp'].skew()
# Out:
# 0.4405398279117744

# %%
dataset3['atemp'].min()
# Out:
# 0.0758

# %%
dataset3['atemp'].std()
# Out:
# 0.06945538873067716

# %%
Upper_Value_atemp = 0.0758 + 3*0.06945538873067716

# %%
Upper_Value_atemp
# Out:
# 0.2841661661920315

# %%
Lower_Value_atemp = 0.0758 - 3*0.06945538873067716

# %%
Lower_Value_atemp
# Out:
# -0.1325661661920315

# %%
dataset3[(dataset3['atemp']>0.2841661661920315) | (dataset3['atemp']<-0.1325661661920315)]
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 15       635 2011-01-29       1   0     1  17    False        6           1
# 33       653 2011-01-30       1   0     1  12    False        0           1
# 34       654 2011-01-30       1   0     1  13    False        0           1
# 35       655 2011-01-30       1   0     1  14    False        0           1
# 36       656 2011-01-30       1   0     1  15    False        0           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 376      996 2011-02-14       1   0     2   3    False        1           1
# 377      997 2011-02-14       1   0     2   4    False        1           1
# 378      998 2011-02-14       1   0     2   5    False        1           1
# 379      999 2011-02-14       1   0     2   6    False        1           1
# 380     1000 2011-02-14       1   0     2   7    False        1           1
#
# ...

# %%
percenile_25th = dataset3['atemp'].quantile(0.25)

# %%
percenile_25th
# Out:
# 0.1818

# %%
percenile_50th = dataset3['atemp'].quantile(0.50)

# %%
percenile_50th
# Out:
# 0.2273

# %%
percenile_75th = dataset3['atemp'].quantile(0.75)

# %%
percenile_75th
# Out:
# 0.2727

# %%
percenile_100th = dataset3['atemp'].quantile(1.0)

# %%
percenile_100th
# Out:
# 0.4242

# %%
iqr = percenile_75th - percenile_25th

# %%
iqr
# Out:
# 0.09090000000000001

# %%
max_side_value = percenile_75th + 1.5*iqr
max_side_value
# Out:
# 0.40905

# %%
mai_side_value = percenile_25th - 1.5*iqr
mai_side_value
# Out:
# 0.04544999999999996

# %%
dataset3[dataset3['atemp'] < mai_side_value]
# Out:
# Empty DataFrame
# Columns: [instant, dteday, season, yr, mnth, hr, holiday, weekday, weathersit, temp, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %%
dataset3[dataset3['atemp'] < max_side_value]
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620 2011-01-29       1   0     1   1    False        6           1
# 1        621 2011-01-29       1   0     1   2    False        6           1
# 2        622 2011-01-29       1   0     1   3    False        6           1
# 3        623 2011-01-29       1   0     1   4    False        6           1
# 4        624 2011-01-29       1   0     1   6    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 385      615 2011-01-28       1   0     1  20    False        5           2
# 386      616 2011-01-28       1   0     1  21    False        5           2
# 387      617 2011-01-28       1   0     1  22    False        5           1
# 388      618 2011-01-28       1   0     1  23    False        5           1
# 389      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %%
sn.boxplot(dataset3['atemp'])
# Out:
# <Axes: ylabel='atemp'>

# %%
sn.scatterplot(dataset3['atemp'])
# Out:
# <Axes: ylabel='atemp'>

# %%
sn.histplot(dataset3['atemp'])
# Out:
# <Axes: xlabel='atemp', ylabel='Count'>
